# %% [markdown]
# ## Template

# %%
import cv2
import pytesseract

# Step 1: Preprocessing
def preprocess_image(image):
    # Apply preprocessing techniques like resizing, noise removal, contrast adjustment, etc.
    # ...

# Step 2: Symbol Detection
def detect_symbols(image):
    # Apply symbol detection techniques like edge detection, contour detection, template matching, etc.
    # ...

# Step 3: Symbol Classification
def classify_symbols(symbols):
    # Apply symbol classification techniques using machine learning or deep learning models
    # ...

# Step 4: Main code
def main():
    # Iterate over each image in the dataset
    for image_path in image_paths:
        # Load the image
        image = cv2.imread(image_path)

        # Step 1: Preprocessing
        preprocessed_image = preprocess_image(image)

        # Step 2: Symbol Detection
        symbols = detect_symbols(preprocessed_image)

        # Step 3: Symbol Classification
        classified_symbols = classify_symbols(symbols)

        # Step 5: Post-processing and Analysis
        # Perform any necessary post-processing and analysis on the classified symbols
        # ...

        # Print or save the results
        # ...

# Run the main code
if __name__ == '__main__':
    main()

# %% [markdown]
# ## Pre-trained Model

# %%
--pip install tensorflow-object-detection-api
# Out:
# ...
#      ------------------------------------ 577.4/577.4 kB 398.8 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ------------------------------------ 238.7/238.7 kB 859.0 kB/s eta 0:00:00
# ...
#      -------------------------------------- 54.5/54.5 kB 567.2 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.1/1.1 MB 463.2 kB/s eta 0:00:00
# ...
#      -------------------------------------- 84.5/84.5 kB 530.2 kB/s eta 0:00:00
# ...
#   Created wheel for tensorflow-object-detection-api: filename=tensorflow_object_detection_api-0.1.1-py3-none-any.whl size=844491 sha256=ca262bd8ab93b594a52619e923db943381b51df11bc32378f4561bfe4c004995
#   Stored in directory: c:\users\lsreeram\appdata\local\pip\cache\wheels\38\6f\73\3c0c70f9a8219c31c96c495b686af1416154b60707fd96a4cd
# Successfully built tensorflow-object-detection-api
# ...
#   Attempting uninstall: Pygments
#     Found existing installation: Pygments 2.11.2
# ...

# %%
|- data/
   |- train/
      |- image1.jpg
      |- image2.jpg
      |- ...
   |- test/
      |- image3.jpg
      |- image4.jpg
      |- ...
   |- annotations/
      |- label_map.pbtxt
      |- train_labels.csv
      |- test_labels.csv
|- model/
   |- pipeline.config
|- scripts/
   |- generate_tfrecord.py
|- pre-trained-models/
   |- faster_rcnn_resnet50_coco/
      |- checkpoint/
      |- saved_model/
|- train.py

# %%
python train.py --pipeline_config_path=model/pipeline.config --model_dir=model/ --num_train_steps=50000 --num_eval_steps=200
