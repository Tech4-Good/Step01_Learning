# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import re

# %%
headers = ({'User-Agent':
            'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36',
            'Accept-Language': 'en-US, en;q=0.5'})

# %%
headers = {'User-Agent': 'Mozilla/5.0',  'Accept-Language': 'en-US, en;q=0.5'}
#headers = {'User-Agent': 'Chrome/111.0.5563.65'}
URL = 'https://www.amazon.in/s?k=bags&crid=2M096C61O4MLT&qid=1653308124&sprefix=ba%2Caps%2C283&ref=sr_pg_1'
webpage = requests.get(URL, headers=headers)
soup = BeautifulSoup(webpage.content, "lxml")

# %%
alls = []
hrefs=[]
for d in soup.findAll('div', attrs={'class':'aok-relative'}):
    
    href = soup.find('a', attrs={'class':'a-link-normal s-underline-text s-underline-link-text s-link-style'})
    #href = soup.find('a', attrs={'id':'href'})
    #link = soup.find("a", attrs={'class':'a-link-normal s-no-outline'})
    #link = soup.find("a", attrs={'class':'a-link-normal s-no-outline'})
    alt_name = d.find('a', attrs={'class':'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'})
    name = d.find('span', attrs={'class':'a-size-medium a-color-base a-text-normal'})

    price= d.find('span', attrs={'class':'a-price-whole'})
    rating = d.find('span', attrs={'class':'a-size-base'})
    reviews_count = d.find('span', attrs={'class':'a-size-base s-underline-text'})
    print(href)
    href=''

    all1=[]
    
    #if link is not None:
     #   link = link.get('href')
      #  all1.append(link)
       #hrefs.append(link)
        ##all1=[]
    
    if alt_name is not None:
        all1.append(alt_name.text)
        #alt_name.text prints extra trailing whitespace at end, fix needed.
    else:
        all1.append('Unknown')
        
    if name is not None:
        all1.append(name.text)
    else:
        all1.append('Unknown Product Name')
        
    if price is not None:
        all1.append(price.text)
    else:
        all1.append('N/A')
        
    if rating is not None:
        all1.append(rating.text)
    else:
        all1.append('0')
        
    if reviews_count is not None:
        all1.append(reviews_count.text)
        alls.append(all1)

#csv_headers = [ 'URL','Alt_name' ,'Product Name', 'Price', 'User_Rating', 'Reviews Count']

csv_headers = [ 'Alt_name' ,'Product Name', 'Price', 'User_Rating', 'Reviews Count']

df = pd.DataFrame(alls)
df.columns=csv_headers
df.to_csv('Amazon_products.csv')
df.head()
#df.tail()
# Out:
# <a class="a-link-normal s-underline-text s-underline-link-text s-link-style" href="/Skybags-Brat-Black-Casual-Backpack/dp/B08Z1HHHTD/ref=ice_ac_b_dpb?crid=2M096C61O4MLT&amp;keywords=bags&amp;qid=1679397865&amp;sprefix=ba%2Caps%2C283&amp;sr=8-1"><span class="rush-component" data-component-props='{"asin":"B08Z1HHHTD","badgeType":"amazons-choice"}' data-component-type="s-status-badge-component" data-render-id="r19ba3oaxo217h2nz1unj6euvqv" data-version-id="v28usty9v50bwt2uoiil1x15caf"><div class="a-row a-badge-region"><span aria-labelledby="B08Z1HHHTD-amazons-choice-label B08Z1HHHTD-amazons-choice-supplementary" class="a-badge" data-a-badge-supplementary-position="right" data-a-badge-type="status" id="B08Z1HHHTD-amazons-choice" tabindex="0"><span aria-hidden="true" class="a-badge-label" data-a-badge-color="sx-gulfstream" id="B08Z1HHHTD-amazons-choice-label"><span class="a-badge-label-inner a-text-ellipsis"><span class="a-badge-text" data-a-badge-color="sx-cloud">Amazon's </span><span cla
# ...

# %%
alls = []
hrefs=[]
for d in soup.findAll('div', attrs={'class':'aok-relative'}):
    
    href = soup.find('a', attrs={'class':'a-link-normal s-underline-text s-underline-link-text s-link-style'})
    
    #href = soup.find('a', attrs={'id':'href'})
    alt_name = d.find('a', attrs={'class':'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'})

    all1=[]
    if href is not None:
        all1.append(href.text)
        hrefs.append(href.text)
    


#csv_headers = [ 'URL','Alt_name' ,'Product Name', 'Price', 'User_Rating', 'Reviews Count']

csv_headers = [ 'Alt_name' ]

df = pd.DataFrame(alls)
print(df.shape)
#df.columns=csv_headers
df.head()
#df.tail()

# %%
# The webpage URL
headers = {'User-Agent': 'Mozilla/5.0',  'Accept-Language': 'en-US, en;q=0.5'}
#headers = {'User-Agent': 'Chrome/111.0.5563.65'}
URL = "https://www.amazon.in/s?k=juice&crid=3BEU07G5USXIT&sprefix=juic%2Caps%2C704&ref=nb_sb_noss_2"

# HTTP Request

webpage = requests.get(URL, headers=headers)
# Soup Object containing all data
soup = BeautifulSoup(webpage.content, "lxml")

# Function to extract Product Title
def get_title(soup):
	
	try:
		# Outer Tag Object
		title = soup.find("span", attrs={"id":'productTitle'})

		# Inner NavigatableString Object
		title_value = title.string

		# Title as a string value
		title_string = title_value.strip()

	except AttributeError:
		title_string = ""	

	return title_string

# Fetch links as List of Tag Objects
links = soup.find_all("a", attrs={'class':'a-link-normal s-no-outline'})
# Store the links
links_list = []
# Loop for extracting links from Tag Objects

for link in links:
    links_list.append(link.get('href'))
    # Loop for extracting product details from each link
df['URL_links']=pd.DataFrame(link_list)
df2= pd.DataFrame(links_list)

    
for link in links_list:
    new_webpage = requests.get("https://www.amazon.in" + link, headers=headers)
    new_soup = BeautifulSoup(new_webpage.content, "lxml")
    # Function calls to display all necessary product information
    #print("Product Title =", get_title(new_soup))
df2.head()

# %%
# The webpage URL
headers = {'User-Agent': 'Mozilla/5.0',  'Accept-Language': 'en-US, en;q=0.5'}
#headers = {'User-Agent': 'Chrome/111.0.5563.65'}
URL = "https://www.amazon.in/s?k=juice&crid=3BEU07G5USXIT&sprefix=juic%2Caps%2C704&ref=nb_sb_noss_2"

# HTTP Request

webpage = requests.get(URL, headers=headers)
# Soup Object containing all data
soup = BeautifulSoup(webpage.content, "lxml")

# Function to extract Product Title
def get_title(soup):
	
	try:
		# Outer Tag Object
		title = soup.find("span", attrs={"id":'productTitle'})

		# Inner NavigatableString Object
		title_value = title.string

		# Title as a string value
		title_string = title_value.strip()

	except AttributeError:
		title_string = ""	

	return title_string

# Fetch links as List of Tag Objects
links = soup.find_all("a", attrs={'class':'a-link-normal s-no-outline'})
# Store the links
links_list = []
# Loop for extracting links from Tag Objects

for link in links:
    links_list.append(link.get('href'))
    # Loop for extracting product details from each link

df2= pd.DataFrame(links_list)
results=[]

for link in links_list:
    new_webpage = requests.get("https://www.amazon.in" + link, headers=headers)
    new_soup = BeautifulSoup(new_webpage.content, "lxml")
    # Function calls to display all necessary product information
    res1=[]
    try:
        # Outer Tag Object
        title = soup.find("span", attrs={"id":'productTitle'})
        # Inner NavigatableString Object
        title_value = title.string
        # Title as a string value
        title_string = title_value.strip()
        res1.append(title_string)
        
    except AttributeError:
        title_string = ''
        res1.append(title_string)
        results.append(res1)
        
    #try:
     #   asin = soup.find('span', attrs={'id': 'asin'})
results_df=pd.DataFrame(results)
#df2.head()
results_df.head()
# Out:
#   0
# 0
# 1
# 2
# 3
# 4

# %%
print('y')
# Out:
# y

# %%
# The webpage URL
headers = {'User-Agent': 'Mozilla/5.0',  'Accept-Language': 'en-US, en;q=0.5'}
#headers = {'User-Agent': 'Chrome/111.0.5563.65'}
URL = 'https://www.amazon.in/Status-Polyviscose-Mat-x23-Multicolour/dp/B01LXH98OZ/ref=sr_1_5?crid=32A9GTKX3AHV3&keywords=mats&qid=1679382959&sprefix=mat%2Caps%2C229&sr=8-5&th=1'

# HTTP Request

webpage = requests.get(URL, headers=headers)
# Soup Object containing all data
soup = BeautifulSoup(webpage.content, "lxml")

results=[]
res1=[]
try:        # Outer Tag Object
    title = soup.find("span", attrs={"id":'productTitle'})
    # Inner NavigatableString Object
    title_value = title.string
    # Title as a string value
    title_string = title_value.strip()
    print(title_string)
    res1.append(title_string)
except AttributeError:
    title_string = ''
    res1.append(title_string)

feature = soup.find('ul', attrs={'class':'a-unordered-list a-vertical a-spacing-mini'})
#feature = soup.find('div', attrs={'id': 'feature-bullets'})
res1.append(feature.text)
results.append(res1)
print(feature.text)

#productDescription

results_df = pd.DataFrame(results)
#results_df.head()
# Out:
# Status Polypropylene Anti Slip Floor Door Mat in Home Kitchen Office Entrance Mats (38x58 cm) (Blue)
#   (Material & Feature) High Quality Nylon adds “Super-Soft” Feel / Comfort. It also increase the product durability. The mat’s construction with Rubber Gel backing for Absorb water instantly & Dries Faster    (Performance) Anti-skid latex backing keep the mat in place even in wet condition. The durable non slip backing will not fade & brings peace-of-mind when used for children/kids or elders.    ( Care & Maintenance) Normal water, gentle cycle machine wash keep the product safe, Hang to dry or flat air dry.    ( Usage) The multipurpose features of mat can protect your feet from cold floor, runner carpet for bedroom,floor mat,runner rug,bedside runner    ( Eco Friendly) Yes, and it is also Mite resistant. Very human friendly.

# %%
# https://scrapeops.io/python-scrapy-playbook/python-scrapy-amazon-product-scraper/
import json
import scrapy
from urllib.parse import urljoin
import re

class AmazonSearchProductSpider(scrapy.Spider):
    name = "amazon_search_product"

    def start_requests(self):
        keyword_list = ['ipad']
        for keyword in keyword_list:
            amazon_search_url = f'https://www.amazon.com/s?k={keyword}&page=1'
            yield scrapy.Request(url=amazon_search_url, callback=self.discover_product_urls, meta={'keyword': keyword, 'page': 1})

    def discover_product_urls(self, response):
        page = response.meta['page']
        keyword = response.meta['keyword'] 

        ## Discover Product URLs
        search_products = response.css("div.s-result-item[data-component-type=s-search-result]")
        for product in search_products:
            relative_url = product.css("h2>a::attr(href)").get()
            product_url = urljoin('https://www.amazon.com/', relative_url).split("?")[0]
            yield scrapy.Request(url=product_url, callback=self.parse_product_data, meta={'keyword': keyword, 'page': page})
            
        ## Get All Pages
        if page == 1:
            available_pages = response.xpath(
                '//*[contains(@class, "s-pagination-item")][not(has-class("s-pagination-separator"))]/text()'
            ).getall()

            last_page = available_pages[-1]
            for page_num in range(2, int(last_page)):
                amazon_search_url = f'https://www.amazon.com/s?k={keyword}&page={page_num}'
                yield scrapy.Request(url=amazon_search_url, callback=self.parse_search_results, meta={'keyword': keyword, 'page': page_num})


    def parse_product_data(self, response):
        image_data = json.loads(re.findall(r"colorImages':.*'initial':\s*(\[.+?\])},\n", response.text)[0])
        variant_data = re.findall(r'dimensionValuesDisplayData"\s*:\s* ({.+?}),\n', response.text)
        feature_bullets = [bullet.strip() for bullet in response.css("#feature-bullets li ::text").getall()]
        price = response.css('.a-price span[aria-hidden="true"] ::text').get("")
        if not price:
            price = response.css('.a-price .a-offscreen ::text').get("")
        yield {
            "name": response.css("#productTitle::text").get("").strip(),
            "price": price,
            "stars": response.css("i[data-hook=average-star-rating] ::text").get("").strip(),
            "rating_count": response.css("div[data-hook=total-review-count] ::text").get("").strip(),
            "feature_bullets": feature_bullets,
            "images": image_data,
            "variant_data": variant_data,
        }

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26544\1297990975.py in <module>
# ----> 1 amazon_search_product
#
# NameError: name 'amazon_search_product' is not defined

# %%
for cell in soup.select('tr.searchbox_black td'):
    print cell.text
# Out:
#   File "C:\Users\lsreeram\AppData\Local\Temp\ipykernel_26544\768222543.py", line 2
#     print cell.text
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(cell.text)?
